# %%
import numpy as np
import pandas as pd
import os
import torch 
from torch import nn, optim 
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torch.utils.data
import matplotlib.pyplot as plt
import time
import itertools
import glob 
from PIL import Image
import csv 
import cv2
import random
import re
from torchvision.transforms import functional as F
from torchvision.ops.boxes import box_iou
import random

# %%
# !pip install --upgrade albumentations
# import albumentations as A

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Problems:
# Seems like model never predict class 0 despite label.
#
# #Observations
# When I run it for low batches the model does dramtically better with way higher mAP.
#
# ## To Do:
#
# ### Try to get the model to infer on black spots by trying the bottom solutions
# ### Try to implement Other metrics
# ###### Find and Download a lot more data that have bad spots and healthy etc.
#
# Try to Understand the concept of the metrics you apply. Currently, mAP.
#
#
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# ###### Find and Download a lot more data that have bad spots and healthy etc.
#
#
# ##### Add to the spreadsheet by getting info about agencies or research that is to help people who suffer from blindness.
#
#
# ## Links
# * Model:
# https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html
# https://kaggle.com/kshitijpatil09/pytorch-mean-absolute-precision-calculation?scriptVersionId=40816383
#
# * Metrics:
# https://manalelaidouni.github.io/manalelaidouni.github.io/Evaluating-Object-Detection-Models-Guide-to-Performance-Metrics.html#precision
# * For Albumentations look at open source github
# For Cropping
# https://github.com/albumentations-team/albumentations/blob/master/albumentations/augmentations/crops/transforms.py
# https://github.com/albumentations-team/albumentations/blob/ae50578a46e5981eccaafee311a3ee0b4b7992b2/albumentations/augmentations/crops/functional.py#L22
#
#
# ##### Youtube Link
# https://www.youtube.com/watch?v=oqXDdxF_Wuw&ab_channel=Roboflow

# %% [markdown]
# # How to solve bad spots problem
# First run the fruit detector -> bouding box over every fruit.
# Then I will crop the image along the bouding box.
# Then run the cropped image through another bounding box detector and get object detection of bad_spots.
#
# # Another solution
# Find Models that can work with neural network object detection crowding.
#
# #Another Solution
# So I can remove the bad spot label and then have
# ["Apple", "Bad Apple", "Strawberry", "Bad Strawberry"] etc.
#
# #Even another solution
# ["Apple", "Specific Apple badspot"]
# Like current model except differtiating against other black spots.

# %%
import zipfile
with zipfile.ZipFile("/content/drive/MyDrive/Fruit Defects Dataset HalfWay.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %%
#For one strawberry batch please drop watermark rows
np.random.seed(42)
torch.manual_seed(42)
strawberry_csv_batch_3 = pd.read_csv("/content/Fruit Defects Dataset /Train/FreshStrawberries/Fresh StrawBerry Batch 3 Labeled/FreshStrawberryBatch3Labels.csv", header = None)
strawberry_csv_batch_2 = pd.read_csv("/content/Fruit Defects Dataset /Train/FreshStrawberries/Fresh StrawBerry Batch 2 Labeled/FreshStrawberriesBatch2Labels.csv", header = None)
strawberry_csv_batch_1 = pd.read_csv("/content/Fruit Defects Dataset /Train/FreshStrawberries/Fresh StrawBerry Batch 1 Labeled/Strawberrybatch1.csv", header = None)
rottenApple_csv_batch_1 = pd.read_csv("/content/Fruit Defects Dataset /Train/RottenApples/RottenAppleBatch1Labeled/RottenAppleBatch1Labels.csv", header = None)
rottenApple_csv_batch_2 = pd.read_csv("/content/Fruit Defects Dataset /Train/RottenApples/RottenAppleBatch2Labeled/RottenApplesBatch2Labels.csv", header = None)
rottenApple_csv_batch_3 = pd.read_csv("/content/Fruit Defects Dataset /Train/RottenApples/RottenAppleBatch3Labaled/RottenApplesBatch3Labels.csv", header = None)
rottenStrawberry_csv_batch_1 = pd.read_csv("/content/Fruit Defects Dataset /Train/RottenStrawberries/Batch1RottenStrawBerryLabels/RottenStrawberriesBatch1Labels.csv", header = None)
rottenStrawberry_csv_batch_2 = pd.read_csv("/content/Fruit Defects Dataset /Train/RottenStrawberries/Batch2RottenStrawBerryLabels/RottenStrawBerryBatch2.csv", header = None)
rottenStrawberry_csv_batch_3 = pd.read_csv("/content/Fruit Defects Dataset /Train/RottenStrawberries/Batch3RottenStrawberrylabel/rottenStrawberryBtch3labels.csv", header = None)

strawberry_csv_batch_3.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
strawberry_csv_batch_2.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
strawberry_csv_batch_1.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
rottenApple_csv_batch_1.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
rottenApple_csv_batch_2.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
rottenApple_csv_batch_3.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
rottenStrawberry_csv_batch_1.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
rottenStrawberry_csv_batch_2.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]
rottenStrawberry_csv_batch_3.columns = ["Fruit", "Coord1", "Coord2", "Coord3", "Coord4", "Image_id", "OneSize", "TwoSize"]

#Drop some watermark data for Fresh StrawBerry Batch 1 Labeled images [59, 9, 93]

# strawberry_csv_batch_1 = strawberry_csv_batch_1[Image_id not in ["FreshStrawberries59.jpeg, FreshStrawberries9.jpeg, FreshStrawberries93.jpeg"]]
strawberry_csv_batch_1.drop(strawberry_csv_batch_1[strawberry_csv_batch_1["Image_id"] == "FreshStrawberries59.jpeg"].index, inplace = True)
strawberry_csv_batch_1.drop(strawberry_csv_batch_1[strawberry_csv_batch_1["Image_id"] == "FreshStrawberries9.jpeg"].index, inplace = True)
strawberry_csv_batch_1.drop(strawberry_csv_batch_1[strawberry_csv_batch_1["Image_id"] == "FreshStrawberries93.jpeg"].index, inplace = True)
strawberry_csv_batch_1 = strawberry_csv_batch_1.reset_index(drop=True)

#Stack all the csv files together. 
list_of_all_dataframes = [strawberry_csv_batch_1, strawberry_csv_batch_2, strawberry_csv_batch_3, rottenApple_csv_batch_1, 
                          rottenApple_csv_batch_2, rottenApple_csv_batch_3, rottenStrawberry_csv_batch_1, rottenStrawberry_csv_batch_2, 
                          rottenStrawberry_csv_batch_3]
fruit_df = pd.concat(list_of_all_dataframes, ignore_index = True)

total_row_sum_check = 0 
for dataframe in list_of_all_dataframes:
  total_row_sum_check += dataframe.shape[0]
print("Checked total rows from all the dataframes combined: {}".format(total_row_sum_check))
def run_dataframe_check():
  assert total_row_sum_check == fruit_df.shape[0]
  print("DataFrame shape: {}".format(fruit_df.shape))
  print("Unique Fruit Labels {}".format(fruit_df["Fruit"].unique()))
  print("Number of Unique Images {}".format(len(fruit_df["Image_id"].unique())))

run_dataframe_check()
# Out:
# Checked total rows from all the dataframes combined: 844
# DataFrame shape: (844, 8)
# Unique Fruit Labels ['Strawberry' 'Apples' 'Bad_Spots']
# Number of Unique Images 246

# %%
#Specify more image types when 
def more_specific_Image_id(image_id, fruit):
  if fruit == "Bad_Spots":
    if re.search("RottenStrawberries", image_id):
      return "Strawberry_Bad_Spot"
    elif re.search("RottenApples", image_id):
      return "Apple_Bad_Spot"
    else:
      raise ValueError("Could not find a match for some of the Image_ids")

  else:
    return fruit

fruit_df["Fruit"] = fruit_df.apply(lambda row: more_specific_Image_id(row.Image_id, row.Fruit), axis = 1)

run_dataframe_check()
# Out:
# DataFrame shape: (844, 8)
# Unique Fruit Labels ['Strawberry' 'Apples' 'Apple_Bad_Spot' 'Strawberry_Bad_Spot']
# Number of Unique Images 246

# %%
#Post Processing 
fruit_df = fruit_df[fruit_df["Image_id"] != "FreshStrawberries15.jpeg"]

# %%
bounding_box_dict = dict()
labels_dict = dict()
#classes = ["Strawberry", "Apples", "Apple_Bad_Spot", "Strawberry_Bad_Spot"]
classes = ["Bad_Spots", "Strawberry", "Apples"]

for row_index in range(len(fruit_df)): 
  current_image_file = fruit_df.iloc[row_index]["Image_id"]
  if current_image_file not in bounding_box_dict:
    bounding_box_dict[current_image_file] = list()
    labels_dict[current_image_file] = list()
  bounding_box_dict[current_image_file].append(fruit_df.iloc[row_index, 1:5].to_list())
  labels_dict[current_image_file].append(classes.index(fruit_df.iloc[row_index, 0]))

print(len(bounding_box_dict))
print(len(labels_dict))
# Out:
# 245
# 245

# %% [markdown]
# ## Class function + util functions

# %%
def ffile_path(image_id, full_image_file_paths):
  for image_path in full_image_file_paths:
    if image_id in image_path:
      return image_path

def find_area_bb(bb_coord):
  bb_coord = bb_coord.numpy()
  area_of_each_bb = list()
  for pair_of_coord in bb_coord:
    area_of_each_bb.append(
        (pair_of_coord[2] - pair_of_coord[0]) * (pair_of_coord[3] - pair_of_coord[1])
    )
  return torch.tensor(area_of_each_bb, dtype=torch.int32)

def convert_min_max(bb_coord):
  for pair_of_coord in bb_coord:
    pair_of_coord[2], pair_of_coord[3] = (pair_of_coord[0] + pair_of_coord[-2]), (pair_of_coord[1] + pair_of_coord[-1])
  return bb_coord

class FruitDetectDataset(object):
  def __init__(self, id_labels, id_bounding_boxes, transforms, mode):

    assert len(id_labels) == len(id_bounding_boxes)
    assert sorted(id_labels.keys()) == sorted(id_bounding_boxes.keys())
    self.imgs_key = sorted(id_labels.keys())

    np.random.shuffle(self.imgs_key)
    if (mode == "train"):
      self.imgs_key = self.imgs_key[:int(len(self.imgs_key) * 0.8)]
    else:
      self.imgs_key = self.imgs_key[int(len(self.imgs_key) * 0.8):]

    self.id_labels = id_labels
    self.id_bounding_boxes = id_bounding_boxes
    self.full_image_file_paths = glob.glob("/content/Fruit Defects Dataset /Train/*/*/*.jpeg")

    self.transforms = transforms

  def __getitem__(self, idx):

    img_path = ffile_path(self.imgs_key[idx], self.full_image_file_paths)    
    img = Image.open(img_path).convert("RGB") ## No Image path sometimes
    boxes = convert_min_max(torch.as_tensor(self.id_bounding_boxes[self.imgs_key[idx]], dtype=torch.float32))
    
    labels = torch.as_tensor(self.id_labels[self.imgs_key[idx]], dtype=torch.int64)
    image_id = torch.tensor([idx])
    area = find_area_bb(boxes)

    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = image_id
    target["area"] = area
    
    #Query about transforms for labels of images
    if self.transforms: 
      img, target = self.transforms(img, target)
    
    
    return img, target

  def __len__(self):
    return len(self.imgs_key)

# %%
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

class ToTensor(object):
    def __call__(self, image, target):
        image = F.to_tensor(image)
        return image, target

# %%
#Using this stack overflow (https://stackoverflow.com/questions/65279115/how-to-use-collate-fn-with-dataloaders)
#(Suppose for example, you want to create batches of a list of varying dimension tensors. The below code pads sequences with 0 until the maximum sequence size of the batch,)
#Collate_fn is a function that is used to process your batches before you pass it to dataloader. In my case since I have different sized images I need a way to stack batches b/c torch.stack won't work.
#So I use zip which can accept tensors of different lengths and make them stacked with the size of the lowest length list given. Therefore stacking all the images in a batch 
#Successfully unlike torch.stack and doing that processing to every batch makes collate_fn vital since I have different image sizes.

def collate_fn(batch):
  return tuple([list(a) for a in zip(*batch)])
    # return tuple(zip(*batch))

train_batch_size = 2
test_batch_size = 2

### Have to use augmentations to finally get train and test transforms
def get_transform(train):
    transform = []
    transform.append(ToTensor())
    if train:
        transform.append(RandomHorizontalFlip(0.5))
    return Compose(transform)

train_dataset = FruitDetectDataset(labels_dict, bounding_box_dict, get_transform(train = False), mode = "train")
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = train_batch_size, shuffle = True, collate_fn= collate_fn)

test_dataset = FruitDetectDataset(labels_dict, bounding_box_dict, get_transform(train = False), mode = "test")
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = test_batch_size, shuffle = True, collate_fn= collate_fn)

# %%
COLORS = [(255, 0, 0), (0, 255, 0), (0, 0 , 255), (255, 255, 0)]

def draw_boxes(boxes, labels, image):
    # read the image with OpenCV
    image = image.permute(1, 2, 0).numpy()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    for i, box in enumerate(boxes):
        color = COLORS[labels[i]]
        cv2.rectangle(
            image,
            (int(box[0]), int(box[1])),
            (int(box[2]), int(box[3])),
            color, 2
        )
        cv2.putText(image, classes[labels[i]], (int(box[0]), int(box[1]-5)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2, 
                    lineType=cv2.LINE_AA)
    return image

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    image = cv2.cvtColor(draw_boxes(labels[idx]["boxes"], labels[idx]["labels"], images[idx]), cv2.COLOR_BGR2RGB)
    plt.imshow(image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## What we learned
# is that the model outputs losses when in train mode
# when in model.eval model, the model code then return only a prediction with no losses.

# %%
def calculate_mAP(target_box,predictions_box,scores, device, thresh= 0.1):

    #Get most confident boxes first and least confident last
    predictions_box = predictions_box[scores.argsort().flip(-1)]
    iou_mat = box_iou(target_box,predictions_box)
    #return a one by one matrix that is form (target_box, prediction_box) or (1, 1)
    target_boxes_count, prediction_boxes_count = iou_mat.shape
    # thresh = torch.tensor(thresh).to(device)
    
    # thresholding
    # iou_mat = iou_mat.where(iou_mat>thresh,torch.tensor(0.))
    
    mAP_Matrix = torch.zeros_like(iou_mat)
    # if not matrix coordinates that relate to nothing.
    if not iou_mat[:,0].eq(0.).all():
      index_of_biggest_iou = iou_mat[:,0].argsort()[-1]
      mAP_Matrix[index_of_biggest_iou,0] = 1

    for pr_idx in range(1,prediction_boxes_count):
        not_assigned = torch.logical_not(mAP_Matrix[:,:pr_idx].sum(1)).long()
        targets = not_assigned * iou_mat[:,pr_idx]

        if targets.eq(0).all():
            continue

        pivot = targets.argsort()[-1]
        mAP_Matrix[pivot,pr_idx] = 1

    # mAP calculation
    tp = mAP_Matrix.sum()
    fp = mAP_Matrix.sum(0).eq(0).sum()
    fn = mAP_Matrix.sum(1).eq(0).sum()
    mAP = tp / (tp+fp+fn)

    
    return mAP

def run_metrics_for_batch(output, targets, mAP, missed_images, device):
  for pos_in_batch, image_pred in enumerate(output):
    assert (len(image_pred["boxes"]) == len(image_pred["labels"]) == len(image_pred["scores"]))
    if len(image_pred["boxes"]) != 0:
      mAP += calculate_mAP(targets[pos_in_batch]["boxes"], output[pos_in_batch]["boxes"], output[pos_in_batch]["scores"], device)
    else:
      missed_images += 1 
  
  return mAP, missed_images

# %%
def train(net, epochs, train_loader, test_loader, lr, 
          print_every = 6, lo_test_dataset = len(test_dataset), lo_train_dataset = len(train_dataset)):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    #Check which parameters can calulate gradients. 
    params = [p for p in net.parameters() if p.requires_grad]
    optimizer = optim.Adam(params, lr = lr)

    net.to(device)
    print("Device: {}".format(device))
    print("Optimizer: {}".format(optimizer))
    
    start_time = time.time()
    
    for epoch in range(epochs):
        net.train()
        
        train_loss = steps = train_mAP = missed_train_images = 0
        
        for batch_idx, (images, targets) in enumerate(train_loader):
            net.train()

            steps += 1

            images = [image.to(device) for image in images]
            targets = [{key: value.to(device) for key, value in t.items()} for t in targets]

            optimizer.zero_grad()
            
            loss_dict = net(images, targets)
            losses = sum(loss for loss in loss_dict.values())

            net.eval()
            train_mAP, missed_train_images = run_metrics_for_batch(net(images), targets, train_mAP, missed_train_images, device)
            net.train()

            losses.backward()
            optimizer.step()

            train_loss +=  losses.item()

            if (steps % print_every) == 0:

              net.eval()
              with torch.no_grad():
                test_mAP = missed_test_images = 0

                for images, targets in test_loader:
                  """ Make sure the batch size is one (for now) for test loader due to sometimes there being empty predictions"""
                  if device == torch.device("cuda"):
                    images = [image.to(device) for image in images]
                    targets = [{key: value.to(device) for key, value in t.items()} for t in targets]

                  output = net(images)
                  test_mAP, missed_test_images = run_metrics_for_batch(output, targets, test_mAP, missed_test_images, device)

                print("Epoch {}/{} | Batch Number: {} | Train_loss: {:0.2f} | Train mAP : {:0.2f}% | Missed Train Images {} | Test mAP: {:0.2f}% | Missed Test Images: {}".format(
                    epoch + 1, epochs, steps, train_loss, (train_mAP / float(lo_train_dataset)) * 100., 
                    missed_train_images, (test_mAP / float(lo_test_dataset)) * 100., missed_test_images))
              assert (steps % print_every) == 0
              train_loss = 0
              net.train()
    
    print("Time for Total Training {:0.2f}".format(time.time() - start_time))
    return net

# %% [markdown]
# ## This link shows the problem https://github.com/pytorch/vision/issues/2740
# The answer from @oke-aditya is correct. You are probably passing to the model bounding boxes in the format [xmin, ymin, width, height], while Faster R-CNN expects boxes to be in [xmin, ymin, xmax, ymax] format.
#
# Changing this should fix the issue.
#
# We have btw recently added box conversion utilities to torchvision (thanks to @oke-aditya ), they can be found in
#
# Look at box convert or doing it locally also works.
#
# ### https://github.com/pytorch/vision/blob/a98e17e50146529cdfadb590ba063e6bbee71de2/torchvision/ops/boxes.py#L137-L156

# %%
import torchvision
backbone = torchvision.models.detection.fasterrcnn_mobilenet_v3_large_320_fpn(pretrained=False)
# backbone.roi_heads.box_predictor.cls_score.out_features = 4
# backbone.roi_heads.box_predictor.bbox_pred.out_features = 16
backbone.roi_heads.box_predictor.cls_score.out_features = 3
backbone.roi_heads.box_predictor.bbox_pred.out_features = 12

# %%
another_one = train(backbone, 10, train_loader, test_loader, 0.001, print_every = 3)
# Out:
# Device: cuda
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Epoch 1/10 | Batch Number: 3 | Train_loss: 15.41 | Train mAP : 0.00% | Missed Train Images 6 | Test mAP: 4.06% | Missed Test Images: 41
# Epoch 1/10 | Batch Number: 6 | Train_loss: 9.86 | Train mAP : 0.17% | Missed Train Images 8 | Test mAP: 6.06% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 9 | Train_loss: 23.71 | Train mAP : 0.52% | Missed Train Images 8 | Test mAP: 11.13% | Missed Test Images: 8
# Epoch 1/10 | Batch Number: 12 | Train_loss: 3.76 | Train mAP : 0.86% | Missed Train Images 9 | Test mAP: 6.61% | Missed Test Images: 12
# Epoch 1/10 | Batch Number: 15 | Train_loss: 2.19 | Train mAP : 1.03% | Missed Train Images 12 | Test mAP: 24.26% | Missed Test Images: 2
# Epoch 1/10 | Batch Number: 18 | Train_loss: 4.05 | Train mAP : 1.29% | Missed Train Images 15 | Test mAP: 6.56% | Missed Test Images: 19
# Epoch 1/10 | Batch Number: 21 | Train_loss: 2.23 | Train mAP : 1.74% | Missed Train Images 16 | Test mAP: 9.31% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 24 | Train_loss: 1.69 | Train mAP : 1.93% | Missed Train Images 19 | Test mAP: 1.93% | Missed Test Images: 27
# Epoch 1/10 | Batch Number: 27 | Train_loss: 2.22 | Train mAP : 2.00% | Missed Train Images 22 | Test mAP: 11.34% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 30 | Train_loss: 2.64 | Train mAP : 2.42% | Missed Train Images 22 | Test mAP: 1.70% | Missed Test Images: 43
# Epoch 1/10 | Batch Number: 33 | Train_loss: 1.24 | Train mAP : 2.42% | Missed Train Images 27 | Test mAP: 0.20% | Missed Test Images: 44
# Epoch 1/10 | Batch Number: 36 | Train_loss: 2.68 | Train mAP : 2.51% | Missed Train Images 31 | Test mAP: 6.10% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 39 | Train_loss: 1.75 | Train mAP : 2.64% | Missed Train Images 31 | Test mAP: 8.48% | Missed Test Images: 3
# Epoch 1/10 | Batch Number: 42 | Train_loss: 2.13 | Train mAP : 2.76% | Missed Train Images 31 | Test mAP: 8.12% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 45 | Train_loss: 1.49 | Train mAP : 2.90% | Missed Train Images 32 | Test mAP: 15.65% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 48 | Train_loss: 2.03 | Train mAP : 3.72% | Missed Train Images 32 | Test mAP: 42.69% | Missed Test Images: 3
# Epoch 1/10 | Batch Number: 51 | Train_loss: 1.33 | Train mAP : 4.74% | Missed Train Images 33 | Test mAP: 45.32% | Missed Test Images: 7
# Epoch 1/10 | Batch Number: 54 | Train_loss: 1.49 | Train mAP : 6.50% | Missed Train Images 33 | Test mAP: 26.24% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 57 | Train_loss: 1.59 | Train mAP : 7.15% | Missed Train Images 33 | Test mAP: 26.92% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 60 | Train_loss: 1.45 | Train mAP : 8.33% | Missed Train Images 33 | Test mAP: 50.43% | Missed Test Images: 3
# Epoch 1/10 | Batch Number: 63 | Train_loss: 1.06 | Train mAP : 9.24% | Missed Train Images 35 | Test mAP: 16.04% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 66 | Train_loss: 0.96 | Train mAP : 9.60% | Missed Train Images 35 | Test mAP: 33.69% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 69 | Train_loss: 1.04 | Train mAP : 10.73% | Missed Train Images 35 | Test mAP: 40.39% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 72 | Train_loss: 1.34 | Train mAP : 11.55% | Missed Train Images 35 | Test mAP: 27.18% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 75 | Train_loss: 1.43 | Train mAP : 11.95% | Missed Train Images 35 | Test mAP: 29.80% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 78 | Train_loss: 1.02 | Train mAP : 12.94% | Missed Train Images 35 | Test mAP: 49.85% | Missed Test Images: 3
# Epoch 1/10 | Batch Number: 81 | Train_loss: 1.22 | Train mAP : 13.48% | Missed Train Images 36 | Test mAP: 16.84% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 84 | Train_loss: 2.10 | Train mAP : 14.07% | Missed Train Images 36 | Test mAP: 25.35% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 87 | Train_loss: 2.06 | Train mAP : 14.60% | Missed Train Images 36 | Test mAP: 11.34% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 90 | Train_loss: 1.26 | Train mAP : 14.96% | Missed Train Images 36 | Test mAP: 36.49% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 93 | Train_loss: 1.88 | Train mAP : 15.64% | Missed Train Images 37 | Test mAP: 51.09% | Missed Test Images: 0
# Epoch 1/10 | Batch Number: 96 | Train_loss: 1.20 | Train mAP : 16.62% | Missed Train Images 37 | Test mAP: 17.51% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 3 | Train_loss: 1.44 | Train mAP : 0.66% | Missed Train Images 0 | Test mAP: 45.53% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 6 | Train_loss: 2.06 | Train mAP : 1.46% | Missed Train Images 0 | Test mAP: 29.95% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 9 | Train_loss: 1.01 | Train mAP : 2.05% | Missed Train Images 0 | Test mAP: 32.20% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 12 | Train_loss: 1.24 | Train mAP : 2.59% | Missed Train Images 0 | Test mAP: 33.75% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 15 | Train_loss: 1.33 | Train mAP : 3.41% | Missed Train Images 0 | Test mAP: 38.64% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 18 | Train_loss: 1.06 | Train mAP : 4.34% | Missed Train Images 0 | Test mAP: 39.80% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 21 | Train_loss: 1.23 | Train mAP : 5.17% | Missed Train Images 0 | Test mAP: 21.68% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 24 | Train_loss: 1.61 | Train mAP : 5.72% | Missed Train Images 0 | Test mAP: 23.19% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 27 | Train_loss: 1.01 | Train mAP : 6.33% | Missed Train Images 0 | Test mAP: 48.84% | Missed Test Images: 1
# Epoch 2/10 | Batch Number: 30 | Train_loss: 1.63 | Train mAP : 7.22% | Missed Train Images 0 | Test mAP: 24.26% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 33 | Train_loss: 1.45 | Train mAP : 7.76% | Missed Train Images 0 | Test mAP: 25.61% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 36 | Train_loss: 1.02 | Train mAP : 8.23% | Missed Train Images 0 | Test mAP: 32.56% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 39 | Train_loss: 2.01 | Train mAP : 9.59% | Missed Train Images 0 | Test mAP: 29.67% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 42 | Train_loss: 1.23 | Train mAP : 10.10% | Missed Train Images 0 | Test mAP: 25.27% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 45 | Train_loss: 1.59 | Train mAP : 10.81% | Missed Train Images 0 | Test mAP: 49.07% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 48 | Train_loss: 1.90 | Train mAP : 12.80% | Missed Train Images 0 | Test mAP: 32.46% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 51 | Train_loss: 1.60 | Train mAP : 13.27% | Missed Train Images 0 | Test mAP: 24.71% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 54 | Train_loss: 1.29 | Train mAP : 14.00% | Missed Train Images 0 | Test mAP: 45.00% | Missed Test Images: 1
# Epoch 2/10 | Batch Number: 57 | Train_loss: 1.52 | Train mAP : 15.40% | Missed Train Images 0 | Test mAP: 26.78% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 60 | Train_loss: 2.02 | Train mAP : 16.32% | Missed Train Images 0 | Test mAP: 23.67% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 63 | Train_loss: 1.21 | Train mAP : 16.90% | Missed Train Images 0 | Test mAP: 35.34% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 66 | Train_loss: 1.65 | Train mAP : 17.68% | Missed Train Images 0 | Test mAP: 30.02% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 69 | Train_loss: 2.32 | Train mAP : 18.72% | Missed Train Images 0 | Test mAP: 27.99% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 72 | Train_loss: 1.39 | Train mAP : 19.32% | Missed Train Images 0 | Test mAP: 47.58% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 75 | Train_loss: 1.72 | Train mAP : 21.04% | Missed Train Images 0 | Test mAP: 41.28% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 78 | Train_loss: 1.86 | Train mAP : 21.99% | Missed Train Images 0 | Test mAP: 27.47% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 81 | Train_loss: 1.13 | Train mAP : 22.75% | Missed Train Images 0 | Test mAP: 36.77% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 84 | Train_loss: 1.53 | Train mAP : 23.85% | Missed Train Images 0 | Test mAP: 52.87% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 87 | Train_loss: 1.81 | Train mAP : 25.07% | Missed Train Images 0 | Test mAP: 33.21% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 90 | Train_loss: 1.72 | Train mAP : 26.42% | Missed Train Images 0 | Test mAP: 47.52% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 93 | Train_loss: 2.50 | Train mAP : 27.54% | Missed Train Images 0 | Test mAP: 35.85% | Missed Test Images: 0
# Epoch 2/10 | Batch Number: 96 | Train_loss: 1.81 | Train mAP : 29.47% | Missed Train Images 0 | Test mAP: 33.26% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 3 | Train_loss: 1.14 | Train mAP : 0.50% | Missed Train Images 0 | Test mAP: 37.18% | Missed Test Images: 1
# Epoch 3/10 | Batch Number: 6 | Train_loss: 1.15 | Train mAP : 1.42% | Missed Train Images 0 | Test mAP: 41.43% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 9 | Train_loss: 1.27 | Train mAP : 2.16% | Missed Train Images 0 | Test mAP: 29.74% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 12 | Train_loss: 1.07 | Train mAP : 3.48% | Missed Train Images 0 | Test mAP: 55.75% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 15 | Train_loss: 0.98 | Train mAP : 4.25% | Missed Train Images 0 | Test mAP: 34.03% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 18 | Train_loss: 1.40 | Train mAP : 5.28% | Missed Train Images 0 | Test mAP: 44.03% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 21 | Train_loss: 1.42 | Train mAP : 6.17% | Missed Train Images 0 | Test mAP: 38.74% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 24 | Train_loss: 1.56 | Train mAP : 7.19% | Missed Train Images 0 | Test mAP: 30.11% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 27 | Train_loss: 2.13 | Train mAP : 8.45% | Missed Train Images 0 | Test mAP: 24.59% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 30 | Train_loss: 1.81 | Train mAP : 8.95% | Missed Train Images 0 | Test mAP: 38.52% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 33 | Train_loss: 1.42 | Train mAP : 10.45% | Missed Train Images 0 | Test mAP: 46.88% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 36 | Train_loss: 1.42 | Train mAP : 11.65% | Missed Train Images 0 | Test mAP: 34.05% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 39 | Train_loss: 1.30 | Train mAP : 12.60% | Missed Train Images 0 | Test mAP: 49.03% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 42 | Train_loss: 1.51 | Train mAP : 13.68% | Missed Train Images 0 | Test mAP: 39.59% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 45 | Train_loss: 1.25 | Train mAP : 15.39% | Missed Train Images 0 | Test mAP: 50.29% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 48 | Train_loss: 1.48 | Train mAP : 16.33% | Missed Train Images 0 | Test mAP: 33.60% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 51 | Train_loss: 1.82 | Train mAP : 17.61% | Missed Train Images 0 | Test mAP: 38.72% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 54 | Train_loss: 1.63 | Train mAP : 19.04% | Missed Train Images 0 | Test mAP: 39.57% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 57 | Train_loss: 1.77 | Train mAP : 20.09% | Missed Train Images 0 | Test mAP: 37.94% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 60 | Train_loss: 1.45 | Train mAP : 21.50% | Missed Train Images 0 | Test mAP: 31.99% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 63 | Train_loss: 1.42 | Train mAP : 22.72% | Missed Train Images 0 | Test mAP: 59.58% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 66 | Train_loss: 1.42 | Train mAP : 24.11% | Missed Train Images 0 | Test mAP: 49.46% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 69 | Train_loss: 0.99 | Train mAP : 25.14% | Missed Train Images 0 | Test mAP: 35.78% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 72 | Train_loss: 1.00 | Train mAP : 26.21% | Missed Train Images 0 | Test mAP: 61.34% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 75 | Train_loss: 1.21 | Train mAP : 27.58% | Missed Train Images 0 | Test mAP: 49.30% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 78 | Train_loss: 1.00 | Train mAP : 29.43% | Missed Train Images 0 | Test mAP: 45.20% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 81 | Train_loss: 1.38 | Train mAP : 30.55% | Missed Train Images 0 | Test mAP: 58.01% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 84 | Train_loss: 1.15 | Train mAP : 32.23% | Missed Train Images 0 | Test mAP: 38.95% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 87 | Train_loss: 1.01 | Train mAP : 33.09% | Missed Train Images 0 | Test mAP: 42.16% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 90 | Train_loss: 1.13 | Train mAP : 34.14% | Missed Train Images 0 | Test mAP: 54.79% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 93 | Train_loss: 1.66 | Train mAP : 36.21% | Missed Train Images 0 | Test mAP: 51.92% | Missed Test Images: 0
# Epoch 3/10 | Batch Number: 96 | Train_loss: 1.13 | Train mAP : 37.64% | Missed Train Images 0 | Test mAP: 53.83% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 3 | Train_loss: 1.00 | Train mAP : 1.42% | Missed Train Images 0 | Test mAP: 51.35% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 6 | Train_loss: 1.13 | Train mAP : 2.68% | Missed Train Images 0 | Test mAP: 47.93% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 9 | Train_loss: 1.20 | Train mAP : 3.82% | Missed Train Images 0 | Test mAP: 60.82% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 12 | Train_loss: 0.95 | Train mAP : 6.40% | Missed Train Images 0 | Test mAP: 58.94% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 15 | Train_loss: 1.13 | Train mAP : 7.78% | Missed Train Images 0 | Test mAP: 34.20% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 18 | Train_loss: 1.05 | Train mAP : 8.94% | Missed Train Images 0 | Test mAP: 51.50% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 21 | Train_loss: 1.35 | Train mAP : 10.18% | Missed Train Images 0 | Test mAP: 56.68% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 24 | Train_loss: 1.29 | Train mAP : 11.22% | Missed Train Images 0 | Test mAP: 49.57% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 27 | Train_loss: 1.15 | Train mAP : 12.28% | Missed Train Images 0 | Test mAP: 45.74% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 30 | Train_loss: 1.07 | Train mAP : 13.18% | Missed Train Images 0 | Test mAP: 52.43% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 33 | Train_loss: 1.11 | Train mAP : 14.57% | Missed Train Images 0 | Test mAP: 50.23% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 36 | Train_loss: 0.83 | Train mAP : 15.79% | Missed Train Images 0 | Test mAP: 50.42% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 39 | Train_loss: 1.41 | Train mAP : 17.45% | Missed Train Images 0 | Test mAP: 45.94% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 42 | Train_loss: 1.55 | Train mAP : 18.74% | Missed Train Images 0 | Test mAP: 48.52% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 45 | Train_loss: 1.50 | Train mAP : 20.76% | Missed Train Images 0 | Test mAP: 35.83% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 48 | Train_loss: 0.87 | Train mAP : 21.51% | Missed Train Images 0 | Test mAP: 31.57% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 51 | Train_loss: 1.17 | Train mAP : 22.95% | Missed Train Images 0 | Test mAP: 56.11% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 54 | Train_loss: 1.27 | Train mAP : 24.18% | Missed Train Images 0 | Test mAP: 59.80% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 57 | Train_loss: 1.26 | Train mAP : 25.64% | Missed Train Images 0 | Test mAP: 56.66% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 60 | Train_loss: 1.13 | Train mAP : 26.51% | Missed Train Images 0 | Test mAP: 43.60% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 63 | Train_loss: 0.95 | Train mAP : 27.77% | Missed Train Images 0 | Test mAP: 52.46% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 66 | Train_loss: 1.42 | Train mAP : 28.86% | Missed Train Images 0 | Test mAP: 48.89% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 69 | Train_loss: 0.95 | Train mAP : 30.02% | Missed Train Images 0 | Test mAP: 57.94% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 72 | Train_loss: 1.15 | Train mAP : 31.38% | Missed Train Images 0 | Test mAP: 61.49% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 75 | Train_loss: 1.25 | Train mAP : 33.13% | Missed Train Images 0 | Test mAP: 57.03% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 78 | Train_loss: 1.10 | Train mAP : 34.60% | Missed Train Images 0 | Test mAP: 59.19% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 81 | Train_loss: 1.31 | Train mAP : 36.63% | Missed Train Images 0 | Test mAP: 53.49% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 84 | Train_loss: 1.18 | Train mAP : 38.24% | Missed Train Images 0 | Test mAP: 67.03% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 87 | Train_loss: 1.07 | Train mAP : 39.62% | Missed Train Images 0 | Test mAP: 56.46% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 90 | Train_loss: 0.96 | Train mAP : 40.91% | Missed Train Images 0 | Test mAP: 50.13% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 93 | Train_loss: 1.22 | Train mAP : 41.83% | Missed Train Images 0 | Test mAP: 59.96% | Missed Test Images: 0
# Epoch 4/10 | Batch Number: 96 | Train_loss: 1.13 | Train mAP : 43.45% | Missed Train Images 0 | Test mAP: 57.88% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 3 | Train_loss: 1.40 | Train mAP : 1.95% | Missed Train Images 0 | Test mAP: 59.19% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 6 | Train_loss: 0.67 | Train mAP : 3.04% | Missed Train Images 0 | Test mAP: 64.74% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 9 | Train_loss: 1.18 | Train mAP : 5.19% | Missed Train Images 0 | Test mAP: 54.77% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 12 | Train_loss: 0.97 | Train mAP : 6.51% | Missed Train Images 0 | Test mAP: 54.14% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 15 | Train_loss: 1.00 | Train mAP : 7.82% | Missed Train Images 0 | Test mAP: 59.48% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 18 | Train_loss: 1.34 | Train mAP : 9.37% | Missed Train Images 0 | Test mAP: 63.96% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 21 | Train_loss: 1.02 | Train mAP : 11.38% | Missed Train Images 0 | Test mAP: 52.43% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 24 | Train_loss: 1.05 | Train mAP : 12.87% | Missed Train Images 0 | Test mAP: 49.52% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 27 | Train_loss: 0.71 | Train mAP : 14.44% | Missed Train Images 0 | Test mAP: 55.90% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 30 | Train_loss: 0.95 | Train mAP : 16.29% | Missed Train Images 0 | Test mAP: 54.66% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 33 | Train_loss: 1.14 | Train mAP : 17.76% | Missed Train Images 0 | Test mAP: 56.49% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 36 | Train_loss: 1.10 | Train mAP : 20.19% | Missed Train Images 0 | Test mAP: 57.94% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 39 | Train_loss: 1.29 | Train mAP : 21.56% | Missed Train Images 0 | Test mAP: 58.54% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 42 | Train_loss: 1.11 | Train mAP : 23.52% | Missed Train Images 0 | Test mAP: 44.50% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 45 | Train_loss: 0.93 | Train mAP : 24.98% | Missed Train Images 0 | Test mAP: 42.14% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 48 | Train_loss: 1.33 | Train mAP : 26.63% | Missed Train Images 0 | Test mAP: 48.24% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 51 | Train_loss: 1.09 | Train mAP : 27.69% | Missed Train Images 0 | Test mAP: 48.44% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 54 | Train_loss: 1.15 | Train mAP : 28.88% | Missed Train Images 0 | Test mAP: 58.73% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 57 | Train_loss: 1.31 | Train mAP : 30.34% | Missed Train Images 0 | Test mAP: 65.67% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 60 | Train_loss: 1.54 | Train mAP : 32.12% | Missed Train Images 0 | Test mAP: 43.99% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 63 | Train_loss: 1.46 | Train mAP : 32.96% | Missed Train Images 0 | Test mAP: 31.78% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 66 | Train_loss: 1.22 | Train mAP : 34.41% | Missed Train Images 0 | Test mAP: 55.58% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 69 | Train_loss: 1.36 | Train mAP : 35.59% | Missed Train Images 0 | Test mAP: 64.73% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 72 | Train_loss: 1.53 | Train mAP : 36.75% | Missed Train Images 0 | Test mAP: 34.73% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 75 | Train_loss: 1.63 | Train mAP : 37.64% | Missed Train Images 0 | Test mAP: 58.90% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 78 | Train_loss: 1.76 | Train mAP : 39.01% | Missed Train Images 0 | Test mAP: 47.98% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 81 | Train_loss: 1.64 | Train mAP : 40.32% | Missed Train Images 0 | Test mAP: 40.46% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 84 | Train_loss: 1.86 | Train mAP : 41.82% | Missed Train Images 0 | Test mAP: 40.81% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 87 | Train_loss: 1.08 | Train mAP : 43.49% | Missed Train Images 0 | Test mAP: 45.64% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 90 | Train_loss: 1.27 | Train mAP : 44.53% | Missed Train Images 0 | Test mAP: 59.17% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 93 | Train_loss: 1.10 | Train mAP : 46.64% | Missed Train Images 0 | Test mAP: 59.51% | Missed Test Images: 0
# Epoch 5/10 | Batch Number: 96 | Train_loss: 1.58 | Train mAP : 48.01% | Missed Train Images 0 | Test mAP: 49.37% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 3 | Train_loss: 1.21 | Train mAP : 1.10% | Missed Train Images 0 | Test mAP: 58.10% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 6 | Train_loss: 0.95 | Train mAP : 2.78% | Missed Train Images 0 | Test mAP: 64.86% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 9 | Train_loss: 1.30 | Train mAP : 4.25% | Missed Train Images 0 | Test mAP: 51.88% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 12 | Train_loss: 1.03 | Train mAP : 5.63% | Missed Train Images 0 | Test mAP: 50.59% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 15 | Train_loss: 1.29 | Train mAP : 6.79% | Missed Train Images 0 | Test mAP: 60.51% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 18 | Train_loss: 1.17 | Train mAP : 8.28% | Missed Train Images 0 | Test mAP: 60.31% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 21 | Train_loss: 1.36 | Train mAP : 10.04% | Missed Train Images 0 | Test mAP: 60.93% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 24 | Train_loss: 0.67 | Train mAP : 11.70% | Missed Train Images 0 | Test mAP: 60.72% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 27 | Train_loss: 0.72 | Train mAP : 13.26% | Missed Train Images 0 | Test mAP: 56.90% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 30 | Train_loss: 0.85 | Train mAP : 14.91% | Missed Train Images 0 | Test mAP: 55.95% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 33 | Train_loss: 0.61 | Train mAP : 16.80% | Missed Train Images 0 | Test mAP: 54.64% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 36 | Train_loss: 1.38 | Train mAP : 18.73% | Missed Train Images 0 | Test mAP: 62.35% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 39 | Train_loss: 0.75 | Train mAP : 20.69% | Missed Train Images 0 | Test mAP: 63.67% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 42 | Train_loss: 0.85 | Train mAP : 22.43% | Missed Train Images 0 | Test mAP: 57.69% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 45 | Train_loss: 0.91 | Train mAP : 24.06% | Missed Train Images 0 | Test mAP: 58.58% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 48 | Train_loss: 1.20 | Train mAP : 25.64% | Missed Train Images 0 | Test mAP: 52.82% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 51 | Train_loss: 1.18 | Train mAP : 27.39% | Missed Train Images 0 | Test mAP: 60.51% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 54 | Train_loss: 0.94 | Train mAP : 28.90% | Missed Train Images 0 | Test mAP: 58.39% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 57 | Train_loss: 1.35 | Train mAP : 30.85% | Missed Train Images 0 | Test mAP: 49.06% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 60 | Train_loss: 1.07 | Train mAP : 31.82% | Missed Train Images 0 | Test mAP: 47.35% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 63 | Train_loss: 1.28 | Train mAP : 32.55% | Missed Train Images 0 | Test mAP: 62.46% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 66 | Train_loss: 1.60 | Train mAP : 34.38% | Missed Train Images 0 | Test mAP: 56.21% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 69 | Train_loss: 0.89 | Train mAP : 35.54% | Missed Train Images 0 | Test mAP: 58.74% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 72 | Train_loss: 1.07 | Train mAP : 37.54% | Missed Train Images 0 | Test mAP: 61.77% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 75 | Train_loss: 1.00 | Train mAP : 39.49% | Missed Train Images 0 | Test mAP: 49.29% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 78 | Train_loss: 1.09 | Train mAP : 40.30% | Missed Train Images 0 | Test mAP: 46.40% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 81 | Train_loss: 1.32 | Train mAP : 41.81% | Missed Train Images 0 | Test mAP: 57.48% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 84 | Train_loss: 1.72 | Train mAP : 43.70% | Missed Train Images 0 | Test mAP: 49.73% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 87 | Train_loss: 1.09 | Train mAP : 45.03% | Missed Train Images 0 | Test mAP: 43.78% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 90 | Train_loss: 0.98 | Train mAP : 46.42% | Missed Train Images 0 | Test mAP: 49.89% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 93 | Train_loss: 0.93 | Train mAP : 47.61% | Missed Train Images 0 | Test mAP: 63.08% | Missed Test Images: 0
# Epoch 6/10 | Batch Number: 96 | Train_loss: 1.21 | Train mAP : 49.31% | Missed Train Images 0 | Test mAP: 56.77% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 3 | Train_loss: 1.51 | Train mAP : 1.22% | Missed Train Images 0 | Test mAP: 61.63% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 6 | Train_loss: 1.21 | Train mAP : 3.07% | Missed Train Images 0 | Test mAP: 63.66% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 9 | Train_loss: 1.32 | Train mAP : 4.32% | Missed Train Images 0 | Test mAP: 49.15% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 12 | Train_loss: 1.19 | Train mAP : 5.68% | Missed Train Images 0 | Test mAP: 60.85% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 15 | Train_loss: 1.49 | Train mAP : 7.76% | Missed Train Images 0 | Test mAP: 33.28% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 18 | Train_loss: 1.68 | Train mAP : 8.57% | Missed Train Images 0 | Test mAP: 50.06% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 21 | Train_loss: 1.58 | Train mAP : 10.67% | Missed Train Images 0 | Test mAP: 53.77% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 24 | Train_loss: 1.39 | Train mAP : 12.31% | Missed Train Images 0 | Test mAP: 41.75% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 27 | Train_loss: 1.53 | Train mAP : 13.43% | Missed Train Images 0 | Test mAP: 41.85% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 30 | Train_loss: 1.31 | Train mAP : 15.01% | Missed Train Images 0 | Test mAP: 51.94% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 33 | Train_loss: 1.59 | Train mAP : 16.52% | Missed Train Images 0 | Test mAP: 49.45% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 36 | Train_loss: 1.48 | Train mAP : 18.22% | Missed Train Images 0 | Test mAP: 50.24% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 39 | Train_loss: 1.30 | Train mAP : 19.53% | Missed Train Images 0 | Test mAP: 37.46% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 42 | Train_loss: 1.09 | Train mAP : 20.29% | Missed Train Images 0 | Test mAP: 37.97% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 45 | Train_loss: 0.76 | Train mAP : 21.34% | Missed Train Images 0 | Test mAP: 51.47% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 48 | Train_loss: 1.03 | Train mAP : 23.20% | Missed Train Images 0 | Test mAP: 63.42% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 51 | Train_loss: 0.92 | Train mAP : 25.23% | Missed Train Images 0 | Test mAP: 61.48% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 54 | Train_loss: 1.14 | Train mAP : 26.43% | Missed Train Images 0 | Test mAP: 53.15% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 57 | Train_loss: 2.19 | Train mAP : 27.98% | Missed Train Images 0 | Test mAP: 55.20% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 60 | Train_loss: 1.15 | Train mAP : 29.66% | Missed Train Images 0 | Test mAP: 52.38% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 63 | Train_loss: 1.30 | Train mAP : 31.40% | Missed Train Images 0 | Test mAP: 56.16% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 66 | Train_loss: 0.88 | Train mAP : 33.21% | Missed Train Images 0 | Test mAP: 56.56% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 69 | Train_loss: 0.84 | Train mAP : 34.76% | Missed Train Images 0 | Test mAP: 51.38% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 72 | Train_loss: 0.88 | Train mAP : 36.18% | Missed Train Images 0 | Test mAP: 57.11% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 75 | Train_loss: 0.77 | Train mAP : 37.75% | Missed Train Images 0 | Test mAP: 54.30% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 78 | Train_loss: 1.31 | Train mAP : 39.77% | Missed Train Images 0 | Test mAP: 50.25% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 81 | Train_loss: 0.90 | Train mAP : 41.28% | Missed Train Images 0 | Test mAP: 48.45% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 84 | Train_loss: 1.12 | Train mAP : 42.47% | Missed Train Images 0 | Test mAP: 53.85% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 87 | Train_loss: 0.84 | Train mAP : 44.11% | Missed Train Images 0 | Test mAP: 63.50% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 90 | Train_loss: 0.84 | Train mAP : 46.49% | Missed Train Images 0 | Test mAP: 64.42% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 93 | Train_loss: 1.07 | Train mAP : 47.83% | Missed Train Images 0 | Test mAP: 60.50% | Missed Test Images: 0
# Epoch 7/10 | Batch Number: 96 | Train_loss: 0.96 | Train mAP : 49.70% | Missed Train Images 0 | Test mAP: 59.26% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 3 | Train_loss: 1.48 | Train mAP : 2.31% | Missed Train Images 0 | Test mAP: 51.90% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 6 | Train_loss: 0.95 | Train mAP : 4.17% | Missed Train Images 0 | Test mAP: 57.05% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 9 | Train_loss: 1.05 | Train mAP : 6.03% | Missed Train Images 0 | Test mAP: 56.47% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 12 | Train_loss: 0.95 | Train mAP : 7.59% | Missed Train Images 0 | Test mAP: 48.87% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 15 | Train_loss: 1.08 | Train mAP : 8.91% | Missed Train Images 0 | Test mAP: 56.08% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 18 | Train_loss: 1.28 | Train mAP : 11.09% | Missed Train Images 0 | Test mAP: 57.37% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 21 | Train_loss: 0.93 | Train mAP : 13.36% | Missed Train Images 0 | Test mAP: 58.54% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 24 | Train_loss: 1.18 | Train mAP : 15.00% | Missed Train Images 0 | Test mAP: 54.35% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 27 | Train_loss: 0.65 | Train mAP : 16.96% | Missed Train Images 0 | Test mAP: 57.66% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 30 | Train_loss: 0.86 | Train mAP : 19.04% | Missed Train Images 0 | Test mAP: 61.98% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 33 | Train_loss: 1.13 | Train mAP : 20.48% | Missed Train Images 0 | Test mAP: 56.47% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 36 | Train_loss: 0.82 | Train mAP : 22.22% | Missed Train Images 0 | Test mAP: 55.68% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 39 | Train_loss: 0.68 | Train mAP : 24.03% | Missed Train Images 0 | Test mAP: 53.19% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 42 | Train_loss: 0.70 | Train mAP : 26.14% | Missed Train Images 0 | Test mAP: 52.05% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 45 | Train_loss: 1.08 | Train mAP : 27.62% | Missed Train Images 0 | Test mAP: 56.56% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 48 | Train_loss: 1.44 | Train mAP : 29.98% | Missed Train Images 0 | Test mAP: 63.12% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 51 | Train_loss: 1.28 | Train mAP : 32.03% | Missed Train Images 0 | Test mAP: 38.50% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 54 | Train_loss: 0.80 | Train mAP : 32.94% | Missed Train Images 0 | Test mAP: 39.68% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 57 | Train_loss: 1.15 | Train mAP : 34.56% | Missed Train Images 0 | Test mAP: 53.40% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 60 | Train_loss: 1.17 | Train mAP : 36.14% | Missed Train Images 0 | Test mAP: 59.52% | Missed Test Images: 1
# Epoch 8/10 | Batch Number: 63 | Train_loss: 1.34 | Train mAP : 37.41% | Missed Train Images 0 | Test mAP: 25.11% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 66 | Train_loss: 1.75 | Train mAP : 38.26% | Missed Train Images 0 | Test mAP: 37.71% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 69 | Train_loss: 0.83 | Train mAP : 39.67% | Missed Train Images 0 | Test mAP: 33.96% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 72 | Train_loss: 0.97 | Train mAP : 40.75% | Missed Train Images 0 | Test mAP: 40.23% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 75 | Train_loss: 1.09 | Train mAP : 41.91% | Missed Train Images 0 | Test mAP: 47.19% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 78 | Train_loss: 0.97 | Train mAP : 43.13% | Missed Train Images 0 | Test mAP: 47.56% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 81 | Train_loss: 1.18 | Train mAP : 44.98% | Missed Train Images 0 | Test mAP: 44.00% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 84 | Train_loss: 1.07 | Train mAP : 45.94% | Missed Train Images 0 | Test mAP: 42.05% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 87 | Train_loss: 1.13 | Train mAP : 47.03% | Missed Train Images 0 | Test mAP: 56.95% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 90 | Train_loss: 0.98 | Train mAP : 48.51% | Missed Train Images 0 | Test mAP: 50.24% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 93 | Train_loss: 1.80 | Train mAP : 49.75% | Missed Train Images 0 | Test mAP: 53.56% | Missed Test Images: 0
# Epoch 8/10 | Batch Number: 96 | Train_loss: 1.09 | Train mAP : 51.05% | Missed Train Images 0 | Test mAP: 54.93% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 3 | Train_loss: 0.83 | Train mAP : 1.11% | Missed Train Images 0 | Test mAP: 47.76% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 6 | Train_loss: 1.06 | Train mAP : 2.51% | Missed Train Images 0 | Test mAP: 57.06% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 9 | Train_loss: 1.39 | Train mAP : 4.21% | Missed Train Images 0 | Test mAP: 60.60% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 12 | Train_loss: 0.94 | Train mAP : 5.73% | Missed Train Images 0 | Test mAP: 58.52% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 15 | Train_loss: 1.01 | Train mAP : 7.53% | Missed Train Images 0 | Test mAP: 41.58% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 18 | Train_loss: 0.93 | Train mAP : 8.53% | Missed Train Images 0 | Test mAP: 44.60% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 21 | Train_loss: 1.10 | Train mAP : 9.47% | Missed Train Images 0 | Test mAP: 58.44% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 24 | Train_loss: 1.27 | Train mAP : 11.45% | Missed Train Images 0 | Test mAP: 55.85% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 27 | Train_loss: 1.54 | Train mAP : 13.01% | Missed Train Images 0 | Test mAP: 51.73% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 30 | Train_loss: 0.88 | Train mAP : 15.37% | Missed Train Images 0 | Test mAP: 54.30% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 33 | Train_loss: 1.32 | Train mAP : 17.02% | Missed Train Images 0 | Test mAP: 50.40% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 36 | Train_loss: 0.88 | Train mAP : 18.55% | Missed Train Images 0 | Test mAP: 46.38% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 39 | Train_loss: 1.13 | Train mAP : 19.71% | Missed Train Images 0 | Test mAP: 57.77% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 42 | Train_loss: 1.33 | Train mAP : 20.93% | Missed Train Images 0 | Test mAP: 61.99% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 45 | Train_loss: 1.47 | Train mAP : 22.42% | Missed Train Images 0 | Test mAP: 57.20% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 48 | Train_loss: 1.31 | Train mAP : 23.92% | Missed Train Images 0 | Test mAP: 58.30% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 51 | Train_loss: 1.18 | Train mAP : 25.53% | Missed Train Images 0 | Test mAP: 59.75% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 54 | Train_loss: 0.73 | Train mAP : 27.92% | Missed Train Images 0 | Test mAP: 56.90% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 57 | Train_loss: 1.02 | Train mAP : 29.56% | Missed Train Images 0 | Test mAP: 61.75% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 60 | Train_loss: 1.17 | Train mAP : 31.50% | Missed Train Images 0 | Test mAP: 62.08% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 63 | Train_loss: 1.16 | Train mAP : 33.74% | Missed Train Images 0 | Test mAP: 59.89% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 66 | Train_loss: 0.85 | Train mAP : 35.75% | Missed Train Images 0 | Test mAP: 60.33% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 69 | Train_loss: 1.23 | Train mAP : 37.57% | Missed Train Images 0 | Test mAP: 57.07% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 72 | Train_loss: 0.97 | Train mAP : 39.29% | Missed Train Images 0 | Test mAP: 61.91% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 75 | Train_loss: 0.88 | Train mAP : 40.50% | Missed Train Images 0 | Test mAP: 58.37% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 78 | Train_loss: 1.16 | Train mAP : 42.50% | Missed Train Images 0 | Test mAP: 53.00% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 81 | Train_loss: 0.81 | Train mAP : 44.24% | Missed Train Images 0 | Test mAP: 49.42% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 84 | Train_loss: 0.77 | Train mAP : 46.49% | Missed Train Images 0 | Test mAP: 56.72% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 87 | Train_loss: 0.92 | Train mAP : 48.28% | Missed Train Images 0 | Test mAP: 62.90% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 90 | Train_loss: 1.12 | Train mAP : 50.15% | Missed Train Images 0 | Test mAP: 60.30% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 93 | Train_loss: 0.83 | Train mAP : 51.69% | Missed Train Images 0 | Test mAP: 60.04% | Missed Test Images: 0
# Epoch 9/10 | Batch Number: 96 | Train_loss: 0.89 | Train mAP : 53.41% | Missed Train Images 0 | Test mAP: 60.86% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 3 | Train_loss: 0.78 | Train mAP : 1.96% | Missed Train Images 0 | Test mAP: 58.43% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 6 | Train_loss: 1.13 | Train mAP : 3.95% | Missed Train Images 0 | Test mAP: 61.06% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 9 | Train_loss: 0.68 | Train mAP : 6.16% | Missed Train Images 0 | Test mAP: 57.37% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 12 | Train_loss: 0.81 | Train mAP : 8.07% | Missed Train Images 0 | Test mAP: 56.90% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 15 | Train_loss: 1.01 | Train mAP : 9.16% | Missed Train Images 0 | Test mAP: 57.47% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 18 | Train_loss: 1.00 | Train mAP : 10.46% | Missed Train Images 0 | Test mAP: 53.73% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 21 | Train_loss: 0.67 | Train mAP : 12.21% | Missed Train Images 0 | Test mAP: 59.49% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 24 | Train_loss: 0.78 | Train mAP : 14.25% | Missed Train Images 0 | Test mAP: 57.89% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 27 | Train_loss: 0.73 | Train mAP : 16.17% | Missed Train Images 0 | Test mAP: 59.55% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 30 | Train_loss: 0.80 | Train mAP : 18.25% | Missed Train Images 0 | Test mAP: 61.34% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 33 | Train_loss: 0.93 | Train mAP : 20.07% | Missed Train Images 0 | Test mAP: 63.23% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 36 | Train_loss: 1.05 | Train mAP : 21.53% | Missed Train Images 0 | Test mAP: 61.82% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 39 | Train_loss: 0.86 | Train mAP : 22.81% | Missed Train Images 0 | Test mAP: 58.40% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 42 | Train_loss: 0.78 | Train mAP : 25.05% | Missed Train Images 0 | Test mAP: 60.07% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 45 | Train_loss: 0.86 | Train mAP : 27.78% | Missed Train Images 0 | Test mAP: 60.29% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 48 | Train_loss: 1.00 | Train mAP : 29.35% | Missed Train Images 0 | Test mAP: 58.60% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 51 | Train_loss: 0.90 | Train mAP : 31.44% | Missed Train Images 0 | Test mAP: 61.75% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 54 | Train_loss: 0.62 | Train mAP : 33.48% | Missed Train Images 0 | Test mAP: 57.92% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 57 | Train_loss: 0.82 | Train mAP : 35.71% | Missed Train Images 0 | Test mAP: 59.25% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 60 | Train_loss: 0.81 | Train mAP : 37.73% | Missed Train Images 0 | Test mAP: 59.05% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 63 | Train_loss: 0.93 | Train mAP : 40.10% | Missed Train Images 0 | Test mAP: 55.58% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 66 | Train_loss: 1.12 | Train mAP : 41.57% | Missed Train Images 0 | Test mAP: 54.30% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 69 | Train_loss: 0.73 | Train mAP : 44.09% | Missed Train Images 0 | Test mAP: 59.08% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 72 | Train_loss: 1.12 | Train mAP : 45.98% | Missed Train Images 0 | Test mAP: 56.41% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 75 | Train_loss: 0.80 | Train mAP : 47.89% | Missed Train Images 0 | Test mAP: 58.46% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 78 | Train_loss: 0.89 | Train mAP : 49.92% | Missed Train Images 0 | Test mAP: 57.36% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 81 | Train_loss: 1.15 | Train mAP : 52.00% | Missed Train Images 0 | Test mAP: 56.76% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 84 | Train_loss: 0.88 | Train mAP : 53.97% | Missed Train Images 0 | Test mAP: 65.67% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 87 | Train_loss: 0.71 | Train mAP : 56.19% | Missed Train Images 0 | Test mAP: 64.58% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 90 | Train_loss: 0.84 | Train mAP : 58.42% | Missed Train Images 0 | Test mAP: 57.92% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 93 | Train_loss: 0.79 | Train mAP : 60.42% | Missed Train Images 0 | Test mAP: 53.87% | Missed Test Images: 0
# Epoch 10/10 | Batch Number: 96 | Train_loss: 1.40 | Train mAP : 62.60% | Missed Train Images 0 | Test mAP: 60.06% | Missed Test Images: 0
# Time for Total Training 288.68

# %%
def infer_image(image_file_path, trained_model, distance_thresh, show_image = True):
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  print("Current device: {}".format(device))

  torch_image = F.to_tensor(Image.open(image_file_path).convert("RGB")).unsqueeze(0).to(device)
  trained_model.to(device)
  trained_model.eval()
  print("Image Size: {}".format(torch_image.size()))

  results = trained_model(torch_image)
  print(results)


  valid_box_count = 0
  for ii, score in enumerate(results[0]["scores"]):
    if score < distance_thresh:
      low_index_start = ii
      break
    else:
      valid_box_count += 1

  if valid_box_count == len(results[0]["scores"]):
    low_index_start = len(results[0]["scores"])
  

  for key in results[0]:
    results[0][key] = results[0][key][:low_index_start]

  if show_image:
    if device == torch.device("cuda"):
      torch_image = torch_image.cpu() 
    plt.imshow(cv2.cvtColor(draw_boxes(results[0]["boxes"], results[0]["labels"], torch_image.squeeze()), cv2.COLOR_BGR2RGB))
  
  return results

# %%
first_results = infer_image("/content/appssss.jpeg", 
            another_one, 0.7)
print(first_results)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Current device: cuda
# Image Size: torch.Size([1, 3, 750, 1000])
# [{'boxes': tensor([[422.9969, 236.2061, 671.9313, 392.1951],
#         [645.0984, 235.1407, 908.9444, 449.3975],
#         [ 38.0953, 391.9177, 309.8445, 573.5821],
#         [309.2539, 396.8479, 562.0068, 611.3967],
#         [229.7288, 245.7967, 402.6302, 411.5341],
#         [  0.0000, 194.8906, 202.9401, 355.2847],
#         [311.8688,  29.3859, 531.1053, 210.7670],
#         [555.5940,  46.5112, 755.9269, 230.6357],
#         [345.6081, 455.2551, 538.1155, 595.5206],
#         [ 23.3637, 204.6864, 270.6162, 621.3892],
#         [409.0636, 184.3354, 706.8554, 446.8742],
#         [  3.8442, 204.9843, 218.0302, 381.7555]], device='cuda:0',
#        grad_fn=<StackBackward>), 'labels': tensor([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1], device='cuda:0'), 'scores': tensor([0.9854, 0.9703, 0.9660, 0.8971, 0.8890, 0.8869, 0.8400, 0.6275, 0.3746,
#         0.2437, 0.1156, 0.0690], device='cuda:0', grad_fn=<IndexBackward>)}]
# [{'boxes': tensor([[422.9969, 236.2061, 671.9313, 392.1951],
#         [645.0984, 235.1407, 908.9444, 449.3975],
#         [ 38.0953, 391.9177, 309.8445, 573.5821],
#         [309.2539, 396.8479, 562.0068, 611.3967],
#         [229.7288, 245.7967, 402.6302, 411.5341],
#         [  0.0000, 194.8906, 202.9401, 355.2847],
#         [311.8688,  29.3859, 531.1053, 210.7670]], device='cuda:0',
#        grad_fn=<SliceBackward>), 'labels': tensor([2, 2, 2, 2, 2, 2, 2], device='cuda:0'), 'scores': tensor([0.9854, 0.9703, 0.9660, 0.8971, 0.8890, 0.8869, 0.8400],
#        device='cuda:0', grad_fn=<SliceBackward>)}]

# %%
second_results = infer_image("/content/starwberyy.jpeg", 
            another_one, 0.7)
print(second_results)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Current device: cuda
# Image Size: torch.Size([1, 3, 225, 225])
# [{'boxes': tensor([[ 43.1360,  34.8710, 121.7179, 102.8083],
#         [ 94.3576, 103.5001, 175.4974, 175.6088],
#         [142.6565, 148.0498, 225.0000, 224.2930],
#         [  2.3363,  93.3649,  80.4237, 158.8907],
#         [135.8751,  30.5980, 224.6640, 103.1943],
#         [154.8916, 159.3944, 208.7827, 209.0027],
#         [ 38.9002, 164.1817, 106.8162, 225.0000],
#         [153.2779,  42.6502, 208.4845,  98.6502],
#         [100.1730, 122.8770, 223.5387, 212.1301],
#         [ 81.4137,  62.8015, 161.3832, 186.7761],
#         [134.2858, 180.8568, 225.0000, 220.1518],
#         [ 31.2690, 165.9468, 116.2585, 225.0000],
#         [ 12.4095,  99.5840,  70.3512, 141.9464],
#         [150.3022, 127.2782, 219.3408, 224.0435],
#         [ 52.4759,  38.6158, 127.5753, 106.7605],
#         [ 89.5249, 103.3041, 169.3050, 166.4868],
#         [127.3175, 175.6839, 225.0000, 218.8084],
#         [ 44.8798, 169.8784, 103.7261, 201.7637],
#         [150.5457,  35.6419, 225.0000, 102.3755]], device='cuda:0',
#        grad_fn=<StackBackward>), 'labels': tensor([2, 1, 1, 1, 2, 1, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 2, 1, 1],
#        device='cuda:0'), 'scores': tensor([0.9461, 0.9261, 0.9240, 0.8916, 0.8715, 0.8271, 0.6123, 0.2540, 0.2529,
#         0.2364, 0.2179, 0.2169, 0.1860, 0.0971, 0.0911, 0.0865, 0.0752, 0.0531,
#         0.0521], device='cuda:0', grad_fn=<IndexBackward>)}]
# [{'boxes': tensor([[ 43.1360,  34.8710, 121.7179, 102.8083],
#         [ 94.3576, 103.5001, 175.4974, 175.6088],
#         [142.6565, 148.0498, 225.0000, 224.2930],
#         [  2.3363,  93.3649,  80.4237, 158.8907],
#         [135.8751,  30.5980, 224.6640, 103.1943],
#         [154.8916, 159.3944, 208.7827, 209.0027]], device='cuda:0',
#        grad_fn=<SliceBackward>), 'labels': tensor([2, 1, 1, 1, 2, 1], device='cuda:0'), 'scores': tensor([0.9461, 0.9261, 0.9240, 0.8916, 0.8715, 0.8271], device='cuda:0',
#        grad_fn=<SliceBackward>)}]

# %%
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

#Got this code from Pytorch
backbone = torchvision.models.mobilenet_v2(pretrained=True).features
backbone.out_channels = 1280
anchor_generator = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                   aspect_ratios=((0.5, 1.0, 2.0),))

roi_pooler = torchvision.ops.MultiScaleRoIAlign(featmap_names=["0"],
                                                output_size=7,
                                                sampling_ratio=2)

model = FasterRCNN(backbone,
                   num_classes= 3,
                   rpn_anchor_generator=anchor_generator,
                   box_roi_pool=roi_pooler)

# %%
big_model_trained = train(model, 5, train_loader, 0.001)
# Out:
# Device: cuda
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Train_loss 75.02
# Train_loss 51.36
# Train_loss 46.14
# Train_loss 41.43
# Train_loss 41.80
# Time for Total Training 239.89
